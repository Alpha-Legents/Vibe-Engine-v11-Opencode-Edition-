# %% [markdown]
# # ⚡ Vibe Engine v11\n## Run on Kaggle with Dual T4\n\n1. Runtime → Accelerator → **GPU T4 x2**\n2. Internet → **On**\n3. Run all cells

# %%
# !wget https://raw.githubusercontent.com/YOUR_USERNAME/YOUR_REPO/main/vibe_engine_v11.py\n%run vibe_engine_v11.py
